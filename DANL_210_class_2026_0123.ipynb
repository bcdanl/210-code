# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/DANL_210_class_2026_0123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5

# %%
y = x + 10

# %%
x
# Out:
# 5

# %%
y
# Out:
# 15

# %%
name_a = 100
name_a
# Out:
# 100

# %%
# below is an assignment example
a = 1
# b = 1

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1685013873.py in <cell line: 0>()
# ----> 1 b
#
# NameError: name 'b' is not defined
