# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_class_2026_0325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv")

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
nba
# Out:
#                Name                 Team Position  Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG   9/26/96   1445697
# 1    Christian Wood      Detroit Pistons       PF   9/27/95   1645357
# 2     PJ Washington    Charlotte Hornets       PF   8/23/98   3831840
# 3      Derrick Rose      Detroit Pistons       PG   10/4/88   7317074
# 4     Marial Shayok   Philadelphia 76ers        G   7/26/95     79568
# ..              ...                  ...      ...       ...       ...
# 445   Austin Rivers      Houston Rockets       PG    8/1/92   2174310
# 446     Harry Giles     Sacramento Kings       PF   4/22/98   2578800
# 447     Robin Lopez      Milwaukee Bucks        C    4/1/88   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG    1/4/99   4764960
# 449     Ricky Rubio         Phoenix Suns       PG  10/21/90  16200000
#
# [450 rows x 5 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      450 non-null    object
#  1   Team      450 non-null    object
#  2   Position  450 non-null    object
#  3   Birthday  450 non-null    object
#  4   Salary    450 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 17.7+ KB

# %%
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
                  parse_dates = ["Birthday"])
nba
# Out:
# /tmp/ipykernel_1056/2686974663.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      450 non-null    object
#  1   Team      450 non-null    object
#  2   Position  450 non-null    object
#  3   Birthday  450 non-null    datetime64[ns]
#  4   Salary    450 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 17.7+ KB

# %%
from google.colab import drive, files
drive.mount('/content/drive')
files.upload()
# Out:
# Mounted at /content/drive
#      <input type="file" id="files-d93159dc-934a-4c3f-8ef1-87f4edffb781" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d93159dc-934a-4c3f-8ef1-87f4edffb781">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
taylor = pd.read_csv("/content/taylor_albums.csv")

# %%
taylor
# Out:
#                              album_name     ep album_release  \
# 0                          Taylor Swift  False    2006-10-24
# 1   The Taylor Swift Holiday Collection   True    2007-10-14
# 2                        Beautiful Eyes   True    2008-07-15
# 3                              Fearless  False    2008-11-11
# 4                             Speak Now  False    2010-10-25
# 5                                   Red  False    2012-10-22
# 6                                  1989  False    2014-10-27
# 7                            reputation  False    2017-11-10
# 8                                 Lover  False    2019-08-23
# 9                              folklore  False    2020-07-24
# 10                             evermore  False    2020-12-11
# 11          Fearless (Taylor's Version)  False    2021-04-09
# 12               Red (Taylor's Version)  False    2021-11-12
# 13                            Midnights  False    2022-10-21
# ...

# %%
nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()  # Enabling an interactive DataFrame display

nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
# Below is to import the pandas library as pd
import pandas as pd

# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

# Below is to read nba.csv as nba DataFrame
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
                  parse_dates = ["Birthday"])
# Out:
# /tmp/ipykernel_1056/788510545.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      450 non-null    object
#  1   Team      450 non-null    object
#  2   Position  450 non-null    object
#  3   Birthday  450 non-null    datetime64[ns]
#  4   Salary    450 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 17.7+ KB

# %%
nba.count()
# Out:
# Name        450
# Team        450
# Position    450
# Birthday    450
# Salary      450
# dtype: int64

# %%
nba.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1056/3127104457.py in <cell line: 0>()
# ----> 1 nba.shape()
#
# TypeError: 'tuple' object is not callable

# %%
nba.shape
# Out:
# (450, 5)

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba.describe()
# Out:
#                   Birthday        Salary
# count                  450  4.500000e+02
# mean   1993-11-24 02:01:36  7.653584e+06
# min    1977-01-26 00:00:00  7.956800e+04
# 25%    1991-03-16 12:00:00  1.618520e+06
# 50%    1994-04-29 00:00:00  3.303074e+06
# 75%    1997-02-17 12:00:00  1.012957e+07
# max    2000-12-23 00:00:00  4.023176e+07
# std                    NaN  9.288810e+06

# %%
type(nba.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
nba.describe(include="all")
# Out:
#                Name                Team Position             Birthday  \
# count           450                 450      450                  450
# unique          450                  30        9                  NaN
# top     Ricky Rubio  Philadelphia 76ers       PG                  NaN
# freq              1                  17       98                  NaN
# mean            NaN                 NaN      NaN  1993-11-24 02:01:36
# min             NaN                 NaN      NaN  1977-01-26 00:00:00
# 25%             NaN                 NaN      NaN  1991-03-16 12:00:00
# 50%             NaN                 NaN      NaN  1994-04-29 00:00:00
# 75%             NaN                 NaN      NaN  1997-02-17 12:00:00
# max             NaN                 NaN      NaN  2000-12-23 00:00:00
# std             NaN                 NaN      NaN                  NaN
#
#               Salary
# count   4.500000e+02
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
nba.max()
# Out:
# Name             Zylan Cheatham
# Team         Washington Wizards
# Position                     SG
# Birthday    2000-12-23 00:00:00
# Salary                 40231758
# dtype: object

# %%
nba.min()
# Out:
# Name               Aaron Gordon
# Team              Atlanta Hawks
# Position                      C
# Birthday    1977-01-26 00:00:00
# Salary                    79568
# dtype: object

# %%
type(nba.min())
# Out:
# pandas.core.series.Series

# %%
nba.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1056/1629379923.py in <cell line: 0>()
# ----> 1 nba.sum()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668         **kwargs,
#   11669     ):
# > 11670         result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671         return result.__finalize__(self, method="sum")
#   11672
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12504         **kwargs,
#   12505     ):
# > 12506         return self._min_count_stat_function(
#   12507             "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508         )
#
# ...

# %%
nba.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1056/3862783939.py in <cell line: 0>()
# ----> 1 nba.mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
nba.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1056/307145598.py in <cell line: 0>()
# ----> 1 nba.median()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
nba.quantile(0.75) # 0 to 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1056/1660458466.py in <cell line: 0>()
# ----> 1 nba.quantile(0.75) # 0 to 1
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   12144             # error: List item 0 has incompatible type "float | ExtensionArray |
#   12145             # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12146             res_df = self.quantile(
#   12147                 [q],  # type: ignore[list-item]
#   12148                 axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   12189             )
#   12190         if method == "single":
# > 12191             res = data._mgr.quantile(qs=q, interpolation=interpolation)
# ...

# %%
nba.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      84             try:
# ---> 85                 return f(*args, **kwargs)
#      86             except ValueError as e:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanvar(values, axis, skipna, ddof, mask)
#    1012     # See https://en.wikipedia.org/wiki/Algorithms_for_calculating_variance
# -> 1013     avg = _ensure_numeric(values.sum(axis=axis, dtype=np.float64)) / count
#    1014     if axis is not None:
#
# ...

# %%
nba.sum(numeric_only = True)
# Out:
# Salary    3444112694
# dtype: int64

# %%
nba.mean(numeric_only = True)
# Out:
# Salary    7.653584e+06
# dtype: float64

# %%
nba.median(numeric_only = True)
# Out:
# Salary    3303074.5
# dtype: float64

# %%
nba.quantile(0.75, numeric_only=True)
# Out:
# Salary    10129574.25
# Name: 0.75, dtype: float64

# %%
nba.std(numeric_only = True)
# Out:
# Salary    9.288810e+06
# dtype: float64

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba["Salary"]
# Out:
# 0       1445697
# 1       1645357
# 2       3831840
# 3       7317074
# 4         79568
#          ...
# 445     2174310
# 446     2578800
# 447     4767000
# 448     4764960
# 449    16200000
# Name: Salary, Length: 450, dtype: int64

# %%
type(nba["Salary"])
# Out:
# pandas.core.series.Series

# %%
nba["Salary"]
# Out:
# 0       1445697
# 1       1645357
# 2       3831840
# 3       7317074
# 4         79568
#          ...
# 445     2174310
# 446     2578800
# 447     4767000
# 448     4764960
# 449    16200000
# Name: Salary, Length: 450, dtype: int64

# %%
nba["Salary"] + nba["Salary"]
# Out:
# 0       2891394
# 1       3290714
# 2       7663680
# 3      14634148
# 4        159136
#          ...
# 445     4348620
# 446     5157600
# 447     9534000
# 448     9529920
# 449    32400000
# Name: Salary, Length: 450, dtype: int64

# %%
1645357 + 1645357
# Out:
# 3290714

# %%
nba["Salary"] + nba["Salary"]
# Out:
# 0       2891394
# 1       3290714
# 2       7663680
# 3      14634148
# 4        159136
#          ...
# 445     4348620
# 446     5157600
# 447     9534000
# 448     9529920
# 449    32400000
# Name: Salary, Length: 450, dtype: int64

# %%
"SUNY" + " Geneseo"
# Out:
# 'SUNY Geneseo'

# %%
nba["Name"] + " (" + nba["Position"] + ")"
# Out:
# 0        Shake Milton (SG)
# 1      Christian Wood (PF)
# 2       PJ Washington (PF)
# 3        Derrick Rose (PG)
# 4        Marial Shayok (G)
#               ...
# 445     Austin Rivers (PG)
# 446       Harry Giles (PF)
# 447        Robin Lopez (C)
# 448     Collin Sexton (PG)
# 449       Ricky Rubio (PG)
# Length: 450, dtype: object

# %%
nba["Salary"].mean()
# Out:
# np.float64(7653583.764444444)

# %%
nba["Salary"]
# Out:
# 0       1445697
# 1       1645357
# 2       3831840
# 3       7317074
# 4         79568
#          ...
# 445     2174310
# 446     2578800
# 447     4767000
# 448     4764960
# 449    16200000
# Name: Salary, Length: 450, dtype: int64

# %%
nba["Salary"] - nba["Salary"].mean()
# Out:
# 0     -6.207887e+06
# 1     -6.008227e+06
# 2     -3.821744e+06
# 3     -3.365098e+05
# 4     -7.574016e+06
#            ...
# 445   -5.479274e+06
# 446   -5.074784e+06
# 447   -2.886584e+06
# 448   -2.888624e+06
# 449    8.546416e+06
# Name: Salary, Length: 450, dtype: float64

# %%
2.886584e+06
# Out:
# 2886584.0

# %%
2.886584e-06
# Out:
# 2.886584e-06

# %%
2.888e-03
# Out:
# 0.002888

# %%
nba['Salary_k'] = nba['Salary'] / 1000

# %%
nba
# Out:
#                Name                 Team Position   Birthday    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
#       Salary_k
# 0     1445.697
# 1     1645.357
# 2     3831.840
# 3     7317.074
# 4       79.568
# ..         ...
# ...

# %%
nba['Salary_2x'] = nba['Salary'] + nba['Salary']
nba['Salary_3x'] = nba['Salary'] * 3

# %%
nba
# Out:
#                Name                 Team Position   Birthday    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
#       Salary_k  Salary_2x  Salary_3x
# 0     1445.697    2891394    4337091
# 1     1645.357    3290714    4936071
# ...
