# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_class_2026_0504.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

fortune1000 = pd.read_csv("https://bcdanl.github.io/data/fortune1000_2025.csv")
fortune = fortune1000[[
    "Rank", "Company", "Sector", "Industry",
    "Revenues_M", "Profits_M", "Number_of_Employees"
]]

# %%
fortune
# Out:
#      Rank                 Company             Sector  \
# 0       1                 Walmart          Retailing
# 1       2                  Amazon          Retailing
# 2       3      UnitedHealth Group        Health Care
# 3       4                   Apple         Technology
# 4       5              CVS Health        Health Care
# ..    ...                     ...                ...
# 995   996                 Datadog         Technology
# 996   997      SBA Communications         Financials
# 997   998           Quad/Graphics              Media
# 998   999  Americold Realty Trust         Financials
# 999  1000     KinderCare Learning  Business Services
#
#                                      Industry  Revenues_M  Profits_M  \
# 0                       General Merchandisers    680990.0    19440.0
# 1             Internet Services and Retailing    637960.0    59250.0
# 2     Health Care: Insurance and Managed Care    400280.0    14400.0
# ...

# %%
url_path = "https://bcdanl.github.io/data/fortune1000_2025_shuffled.csv"
fortune_shuffled = pd.read_csv(url_path)
sectors = fortune_shuffled.groupby("Sector")

fortune_shuffled
# Out:
#      Rank                    Company Ticker       Sector  \
# 0     522            Arista Networks   ANET   Technology
# 1     738              Upbound Group   UPBD    Retailing
# 2     741                Hyster-Yale     HY  Industrials
# 3     661              First Horizon    FHN   Financials
# 4     412                   Celanese     CE    Chemicals
# ..    ...                        ...    ...          ...
# 995   107        Abbott Laboratories    ABT  Health Care
# 996   271  Universal Health Services    UHS  Health Care
# 997   861        Extra Space Storage    EXR   Financials
# 998   436                    KeyCorp    KEY   Financials
# 999   103                        Dow    DOW    Chemicals
#
#                                        Industry             City  \
# 0    Network and Other Communications Equipment      Santa Clara
# 1                    Specialty Retailers: Other            Plano
# 2                          Industrial Machinery        Cleveland
# ...

# %%
fortune_shuffled['Sector'].nunique()
# Out:
# 21

# %%
fortune_shuffled['Sector'].value_counts()
# Out:
# Sector
# Financials                       178
# Technology                        99
# Energy                            97
# Retailing                         85
# Health Care                       83
# Business Services                 59
# Industrials                       46
# Materials                         45
# Transportation                    37
# Food, Beverages & Tobacco         36
# Wholesalers                       33
# Engineering & Construction        31
# Hotels, Restaurants & Leisure     28
# Media                             26
# Chemicals                         24
# Household Products                22
# Aerospace & Defense               21
# Motor Vehicles & Parts            19
# Apparel                           14
# Telecommunications                 9
# Food & Drug Stores                 8
# Name: count, dtype: int64

# %%
sectors.apply(lambda df: df.nlargest(1, "Revenues_M", keep="all"))
# Out:
# /tmp/ipykernel_834/1196263043.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sectors.apply(lambda df: df.nlargest(1, "Revenues_M", keep="all"))
#                                    Rank                   Company Ticker  \
# Sector
# Aerospace & Defense           675    54                       RTX    RTX
# Apparel                       473    90                      Nike    NKE
# Business Services             549   127                      Visa      V
# Chemicals                     999   103                       Dow    DOW
# Energy                        298     8               Exxon Mobil    XOM
# Engineering & Construction    726   123               D.R. Horton    DHI
# ...

# %%
sectors.apply(lambda df: df.nlargest(3, "Revenues_M", keep="all"))
# Out:
# /tmp/ipykernel_834/2538359886.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sectors.apply(lambda df: df.nlargest(3, "Revenues_M", keep="all"))
#                          Rank                 Company Ticker  \
# Sector
# Aerospace & Defense 675    54                     RTX    RTX
#                     959    59         Lockheed Martin    LMT
#                     868    63                  Boeing     BA
# Apparel             473    90                    Nike    NKE
#                     341   405                      VF    VFC
# ...                       ...                     ...    ...
# Transportation      626    49                   FedEx    FDX
# ...

# %%
def get_nlargest_obs(df, n, var):
  return df.nlargest(n, var, keep="all")

# %%
sectors

# %%
sectors.apply(get_nlargest_obs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, include_groups, *args, **kwargs)
#    1823             try:
# -> 1824                 result = self._python_apply_general(f, self._selected_obj)
#    1825                 if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1884         """
# -> 1885         values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886         if not_indexed_same is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in apply_groupwise(self, f, data, axis)
#     918             group_axes = group.axes
# --> 919             res = f(group)
# ...

# %%
sectors.apply(get_nlargest_obs, 3, "Revenues_M")
# Out:
# /tmp/ipykernel_834/3870767964.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sectors.apply(get_nlargest_obs, 3, "Revenues_M")
#                          Rank                 Company Ticker  \
# Sector
# Aerospace & Defense 675    54                     RTX    RTX
#                     959    59         Lockheed Martin    LMT
#                     868    63                  Boeing     BA
# Apparel             473    90                    Nike    NKE
#                     341   405                      VF    VFC
# ...                       ...                     ...    ...
# Transportation      626    49                   FedEx    FDX
# ...

# %%
def filter_by_threshold(df, column, threshold):
    threshold = df[column].quantile(.95)
    return df[ df[column] > threshold ]

sectors.apply(filter_by_threshold, "Revenues_M", 100000)
# Out:
# /tmp/ipykernel_834/1297249700.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sectors.apply(filter_by_threshold, "Revenues_M", 100000)
#                                    Rank                   Company Ticker  \
# Sector
# Aerospace & Defense           675    54                       RTX    RTX
# Apparel                       473    90                      Nike    NKE
# Business Services             9     137           PayPal Holdings   PYPL
#                               549   127                      Visa      V
#                               676   152                Mastercard     MA
# Chemicals                     373   174                        3M    MMM
# ...

# %%
fortune_shuffled["threshold"] = (
    fortune_shuffled
    .groupby('Sector')["Revenues_M"]
    .transform(
        lambda s: s.quantile(.95)
    )
)

# %%
fortune_shuffled
# Out:
#      Rank                    Company Ticker       Sector  \
# 0     522            Arista Networks   ANET   Technology
# 1     738              Upbound Group   UPBD    Retailing
# 2     741                Hyster-Yale     HY  Industrials
# 3     661              First Horizon    FHN   Financials
# 4     412                   Celanese     CE    Chemicals
# ..    ...                        ...    ...          ...
# 995   107        Abbott Laboratories    ABT  Health Care
# 996   271  Universal Health Services    UHS  Health Care
# 997   861        Extra Space Storage    EXR   Financials
# 998   436                    KeyCorp    KEY   Financials
# 999   103                        Dow    DOW    Chemicals
#
#                                        Industry             City  \
# 0    Network and Other Communications Equipment      Santa Clara
# 1                    Specialty Retailers: Other            Plano
# 2                          Industrial Machinery        Cleveland
# ...

# %%
top5perc = fortune_shuffled[
    fortune_shuffled["Revenues_M"] >= fortune_shuffled['threshold']
]

top5perc
# Out:
#      Rank                   Company Ticker                         Sector  \
# 9     137           PayPal Holdings   PYPL              Business Services
# 31    140                     Nucor    NUE                      Materials
# 54     24                Home Depot     HD                      Retailing
# 55     31                    Nvidia   NVDA                     Technology
# 57     11            JPMorgan Chase    JPM                     Financials
# 97     89                     Deere     DE                    Industrials
# 98     64               Caterpillar    CAT                    Industrials
# 135    56                     Sysco    SYY                    Wholesalers
# 138    26  Walgreens Boots Alliance    WBA             Food & Drug Stores
# 139    73                 TD Synnex    SNX                    Wholesalers
# 140    45                   PepsiCo    PEP      Food, Beverages & Tobacco
# 200    30    Verizon Communications     VZ             Telecommunications
# ...

# %%
sectors.apply(lambda d, n: df.nlargest(2, "Revenues_M", keep="all"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, include_groups, *args, **kwargs)
#    1823             try:
# -> 1824                 result = self._python_apply_general(f, self._selected_obj)
#    1825                 if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1884         """
# -> 1885         values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1886         if not_indexed_same is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in apply_groupwise(self, f, data, axis)
#     918             group_axes = group.axes
# --> 919             res = f(group)
# ...

# %% [markdown]
# # Classwork 17

# %%
cereal = pd.read_csv('https://bcdanl.github.io/data/cereals_oatmeal.csv')
cereal
# Out:
#                          Name    Manufacturer  Type  Calories  Fiber  Sugars
# 0                   100% Bran         Nabisco  Cold        70   10.0       6
# 1           100% Natural Bran     Quaker Oats  Cold       120    2.0       8
# 2                    All-Bran       Kellogg's  Cold        70    9.0       5
# 3   All-Bran with Extra Fiber       Kellogg's  Cold        50   14.0       0
# 4              Almond Delight  Ralston Purina  Cold       110    1.0       8
# ..                        ...             ...   ...       ...    ...     ...
# 72                    Triples   General Mills  Cold       110    0.0       3
# 73                       Trix   General Mills  Cold       110    0.0      12
# 74                 Wheat Chex  Ralston Purina  Cold       100    3.0       3
# 75                   Wheaties   General Mills  Cold       100    3.0       3
# 76        Wheaties Honey Gold   General Mills  Cold       110    1.0       8
#
# [77 rows x 6 columns]

# %%
cereal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          77 non-null     object
#  1   Manufacturer  77 non-null     object
#  2   Type          77 non-null     object
#  3   Calories      77 non-null     int64
#  4   Fiber         77 non-null     float64
#  5   Sugars        77 non-null     int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 3.7+ KB

# %% [markdown]
# ## Q1
# Group the data by Manufacturer, and determine the number of groups and the number of cereals per group.

# %%
cereal['Manufacturer'].unique()
# Out:
# array(['Nabisco', 'Quaker Oats', "Kellogg's", 'Ralston Purina',
#        'General Mills', 'Post', 'American Home Food Products'],
#       dtype=object)

# %%
cereal['Manufacturer'].nunique()
# Out:
# 7

# %%
len(
    cereal.groupby('Manufacturer')
)
# Out:
# 7

# %%
(
    cereal
    .groupby('Manufacturer')
    .size()
)
# Out:
# Manufacturer
# American Home Food Products     1
# General Mills                  22
# Kellogg's                      23
# Nabisco                         6
# Post                            9
# Quaker Oats                     8
# Ralston Purina                  8
# dtype: int64

# %%
(
    cereal['Manufacturer']
    .value_counts()
)
# Out:
# Manufacturer
# Kellogg's                      23
# General Mills                  22
# Post                            9
# Ralston Purina                  8
# Quaker Oats                     8
# Nabisco                         6
# American Home Food Products     1
# Name: count, dtype: int64

# %% [markdown]
# ## Q2
# Calculate the mean of the Calories, Fiber, and Sugars for every manufacturer.

# %%
q2 = (
    cereal
    .groupby('Manufacturer')
    .agg(
        Calories_mean = ("Calories", "mean"),
        Fiber_mean = ("Fiber", "mean"),
        Sugars_mean = ("Sugars", "mean"),

    )
)

q2
# Out:
#                              Calories_mean  Fiber_mean  Sugars_mean
# Manufacturer
# American Home Food Products     100.000000    0.000000     3.000000
# General Mills                   111.363636    1.272727     7.954545
# Kellogg's                       108.695652    2.739130     7.565217
# Nabisco                          86.666667    4.000000     1.833333
# Post                            108.888889    2.777778     8.777778
# Quaker Oats                      95.000000    1.337500     5.250000
# Ralston Purina                  115.000000    1.875000     6.125000

# %% [markdown]
# ## Q3
# Create a new DataFrame that includes the maximum Sugars and the minimum Fiber per manufacturer.

# %%
q3 = (
    cereal
    .groupby('Manufacturer')
    .agg(
        Sugars_max = ("Sugars", "max"),
        Fiber_min = ("Fiber", "min")
    )
)

q3
# Out:
#                              Sugars_max  Fiber_min
# Manufacturer
# American Home Food Products           3        0.0
# General Mills                        14        0.0
# Kellogg's                            15        0.0
# Nabisco                               6        1.0
# Post                                 15        0.0
# Quaker Oats                          12        0.0
# Ralston Purina                       11        0.0

# %% [markdown]
# ## Q4
# Add a Normalized_Sugars variable to the cereal DataFrame that standardizes each cereal’s sugar content within its manufacturer group.

# %%
cereal['Normalized_Sugars'] = (
    cereal
    .groupby('Manufacturer')['Sugars']
    .transform(
        lambda s: ( s - s.mean() ) / s.std()
    )
)

cereal
# Out:
#                          Name    Manufacturer  Type  Calories  Fiber  Sugars  \
# 0                   100% Bran         Nabisco  Cold        70   10.0       6
# 1           100% Natural Bran     Quaker Oats  Cold       120    2.0       8
# 2                    All-Bran       Kellogg's  Cold        70    9.0       5
# 3   All-Bran with Extra Fiber       Kellogg's  Cold        50   14.0       0
# 4              Almond Delight  Ralston Purina  Cold       110    1.0       8
# ..                        ...             ...   ...       ...    ...     ...
# 72                    Triples   General Mills  Cold       110    0.0       3
# 73                       Trix   General Mills  Cold       110    0.0      12
# 74                 Wheat Chex  Ralston Purina  Cold       100    3.0       3
# 75                   Wheaties   General Mills  Cold       100    3.0       3
# 76        Wheaties Honey Gold   General Mills  Cold       110    1.0       8
#
#     Normalized_Sugars
# ...

# %% [markdown]
# ## Q5
# Put the two highest-sugar cereals for every manufacturer in a new DataFrame.

# %%
q5 = (
    cereal
    .groupby('Manufacturer')
    .apply(
        lambda df: df.nlargest(2, "Sugars", keep = "all")
    )
)

q5
# Out:
# /tmp/ipykernel_834/3996318948.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(
#                                                              Name  \
# Manufacturer
# American Home Food Products 43                              Maypo
# General Mills               70                  Total Raisin Bran
#                             14                        Cocoa Puffs
#                             18                      Count Chocula
# Kellogg's                   66                             Smacks
#                             6                         Apple Jacks
# Nabisco                     0                           100% Bran
# ...

# %% [markdown]
# ## Q6
# Compute the correlation between Calories and Sugars for each manufacturer.
#
# corr() calculates the correlation between SERIES_1 and SERIES_2.

# %%
cereal["Calories"].corr( cereal["Sugars"] ) # returns a correlation value
# Out:
# np.float64(0.5623402898034883)

# %%
cereal[["Calories", "Sugars"]].corr() # returns a DataFrame of correlation matrix
# Out:
#           Calories   Sugars
# Calories   1.00000  0.56234
# Sugars     0.56234  1.00000

# %%
cereal[["Calories", "Sugars", "Fiber"]].corr() # returns a DataFrame of correlation matrix
# Out:
#           Calories    Sugars     Fiber
# Calories  1.000000  0.562340 -0.293413
# Sugars    0.562340  1.000000 -0.141205
# Fiber    -0.293413 -0.141205  1.000000

# %%
q6 = (
    cereal
    .groupby('Manufacturer')[["Calories", "Sugars"]]
    .corr()
)

q6
# Out:
#                                       Calories    Sugars
# Manufacturer
# American Home Food Products Calories       NaN       NaN
#                             Sugars         NaN       NaN
# General Mills               Calories  1.000000  0.392839
#                             Sugars    0.392839  1.000000
# Kellogg's                   Calories  1.000000  0.548607
#                             Sugars    0.548607  1.000000
# Nabisco                     Calories  1.000000 -0.564692
#                             Sugars   -0.564692  1.000000
# Post                        Calories  1.000000  0.175624
#                             Sugars    0.175624  1.000000
# Quaker Oats                 Calories  1.000000  0.795361
#                             Sugars    0.795361  1.000000
# Ralston Purina              Calories  1.000000  0.769039
#                             Sugars    0.769039  1.000000

# %%
def calc_corr(df, var_1, var_2):
  return df[var_1].corr( df[var_2] )

(
    cereal
    .groupby("Manufacturer")
    .apply(calc_corr, "Calories", "Sugars")
)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2914: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /tmp/ipykernel_834/3608158440.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(calc_corr, "Calories", "Sugars")
# Manufacturer
# American Home Food Products         NaN
# ...

# %%
def calc_corr(df, var_1, var_2):
  return df[[var_1, var_2]].corr()

(
    cereal
    .groupby("Manufacturer")
    .apply(calc_corr, "Calories", "Sugars")
)
# Out:
# /tmp/ipykernel_834/4074447678.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(calc_corr, "Calories", "Sugars")
#                                       Calories    Sugars
# Manufacturer
# American Home Food Products Calories       NaN       NaN
#                             Sugars         NaN       NaN
# General Mills               Calories  1.000000  0.392839
#                             Sugars    0.392839  1.000000
# Kellogg's                   Calories  1.000000  0.548607
#                             Sugars    0.548607  1.000000
# Nabisco                     Calories  1.000000 -0.564692
#                             Sugars   -0.564692  1.000000
# ...
