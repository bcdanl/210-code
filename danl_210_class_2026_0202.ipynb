# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_class_2026_0202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
int("20")
float("14.3")
str(5)
# Out:
# '5'

# %%
int("xyz")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-215267306.py in <cell line: 0>()
# ----> 1 int("xyz")
#
# ValueError: invalid literal for int() with base 10: 'xyz'

# %%
float("xy")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1624839427.py in <cell line: 0>()
# ----> 1 float("xy")
#
# ValueError: could not convert string to float: 'xy'

# %%
float("$10.25")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2831353266.py in <cell line: 0>()
# ----> 1 float("$10.25")
#
# ValueError: could not convert string to float: '$10.25'

# %%
lst = [1,2,3,4]

type(lst)
# Out:
# list

# %%
len(lst)
# Out:
# 4

# %%
max(lst)
# Out:
# 4

# %%
sum(lst)
# Out:
# 10

# %%
print("Cherry", "Strawberry", "Key Lime")
# Out:
# Cherry Strawberry Key Lime

# %%
print("Cherry", "Strawberry", "Key Lime", sep = "!")
# Out:
# Cherry!Strawberry!Key Lime

# %%
print("Cherry", "Strawberry", "Key Lime", sep=" ")
# Out:
# Cherry Strawberry Key Lime

# %% [markdown]
# ## Classwork 2.5
#
# Write a Python code that uses print() and max() functions to print out the largest value in the list, list_variable, as follows:
#
# The largest value in the list is: 1000

# %%
list_variable = [100, 144, 169, 1000, 8]

# %%
largest_value = max(list_variable)
largest_value
# Out:
# 1000

# %%
print("The largest value in the list is:", largest_value)
# Out:
# The largest value in the list is: 1000

# %%
print(f"The largest value in the list is: {largest_value}")
# Out:
# The largest value in the list is: 1000

# %% [markdown]
# # Loop

# %%
count = 1
count += 1
print(count)
# Out:
# 2

# %%
count = 1
count += 2
print(count)
# Out:
# 3

# %%
count = 1
count += 10
print(count)
# Out:
# 11

# %%
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count
# Out:
# 6

# %%
stuff = input()
# Out:
# 10

# %%
# Type something and press Return/Enter on Python Console
# before running print(stuff)
print(stuff)
# Out:
# 10

# %%
type(stuff)
# Out:
# str

# %%
while True:
    user_input = input("Enter 'yes' to continue or 'no' to stop: ")
    if user_input.lower() == 'no':
        print("Exiting the loop. Goodbye!")
        break
    elif user_input.lower() == 'yes':
        print("You chose to continue.")
    else:
        print("Invalid input, please enter 'yes' or 'no'.")
# Out:
# Enter 'yes' to continue or 'no' to stop: yes
# You chose to continue.
# Enter 'yes' to continue or 'no' to stop: YES
# You chose to continue.
# Enter 'yes' to continue or 'no' to stop: yesssss
# Invalid input, please enter 'yes' or 'no'.
# Enter 'yes' to continue or 'no' to stop: no
# Exiting the loop. Goodbye!

# %%
user_input
# Out:
# 'no'

# %%
user_input.lower()
# Out:
# 'no'

# %%
while True:
    value = input("Integer, please [q to quit]: ")
    if value == 'q': # quit
        break
    number = int(value)
    if number % 2 == 0: # an even number
        continue
    print(number, "squared is", number*number)
# Out:
# Integer, please [q to quit]: 5
# 5 squared is 25
# Integer, please [q to quit]: 2
# Integer, please [q to quit]: 3
# 3 squared is 9
# Integer, please [q to quit]: 4
# Integer, please [q to quit]: q

# %%
word = 'thud'
for letter in word:
    print(letter)
# Out:
# t
# h
# u
# d
