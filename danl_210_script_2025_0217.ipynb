# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_script_2025_0217.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Below is to import the pandas library as pd
import pandas as pd

# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

# Below is to read nba.csv as nba DataFrame
nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
                  parse_dates = ["Birthday"])
# Out:
# <ipython-input-1-f4b4f02b546c>:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   nba = pd.read_csv("https://bcdanl.github.io/data/nba.csv",

# %%
nba2 = nba.set_index("Name")

# %%
nba2.loc[
    "LeBron James",
    "Team"
]
# Out:
# 'Los Angeles Lakers'

# %%
nba2.loc[
     "James Harden",
      ["Position", "Birthday"]
]
# Out:
# Position                     PG
# Birthday    1989-08-26 00:00:00
# Name: James Harden, dtype: object

# %%
nba2.loc[
    ["Russell Westbrook", "Anthony Davis"],
     ["Team", "Salary"]
]
# Out:
#                                  Team    Salary
# Name
# Russell Westbrook     Houston Rockets  38506482
# Anthony Davis      Los Angeles Lakers  27093019

# %%
nba2.loc[
    "Joel Embiid",
    "Position":"Salary"
]
# Out:
# Position                      C
# Birthday    1994-03-16 00:00:00
# Salary                 27504630
# Name: Joel Embiid, dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      450 non-null    object
#  1   Team      450 non-null    object
#  2   Position  450 non-null    object
#  3   Birthday  450 non-null    datetime64[ns]
#  4   Salary    450 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 17.7+ KB

# %%
nba.max()
# Out:
# Name             Zylan Cheatham
# Team         Washington Wizards
# Position                     SG
# Birthday    2000-12-23 00:00:00
# Salary                 40231758
# dtype: object

# %%
nba
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]

# %%
nba.min()
# Out:
# Name               Aaron Gordon
# Team              Atlanta Hawks
# Position                      C
# Birthday    1977-01-26 00:00:00
# Salary                    79568
# dtype: object

# %%
nba.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-73a487ed51c9> in <cell line: 0>()
# ----> 1 nba.sum()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668         **kwargs,
#   11669     ):
# > 11670         result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671         return result.__finalize__(self, method="sum")
#   11672
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12504         **kwargs,
#   12505     ):
# > 12506         return self._min_count_stat_function(
#   12507             "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508         )
#
# ...

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary'], dtype='object')

# %%
nba[['Name', 'Team', 'Position', 'Salary']].sum()
# Out:
# Name        Shake MiltonChristian WoodPJ WashingtonDerrick...
# Team        Philadelphia 76ersDetroit PistonsCharlotte Hor...
# Position    SGPFPFPGGPFSGSFCSFPGPGFCPGSGPFCCPFPFSGPFPGSGSF...
# Salary                                             3444112694
# dtype: object

# %%
nba.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-396979259f00> in <cell line: 0>()
# ----> 1 nba.mean()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
nba[['Name', 'Team', 'Position', 'Salary']].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e2f2eb1a0937> in <cell line: 0>()
# ----> 1 nba[['Name', 'Team', 'Position', 'Salary']].mean()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
nba[['Salary']].mean()
# Out:
# Salary    7.653584e+06
# dtype: float64

# %%
nba.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-39a7835f5b37> in <cell line: 0>()
# ----> 1 nba.median()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
nba['Salary'].median()
# Out:
# 3303074.5

# %%
nba.quantile(0.75)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cd4576cd55e8> in <cell line: 0>()
# ----> 1 nba.quantile(0.75)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   12144             # error: List item 0 has incompatible type "float | ExtensionArray |
#   12145             # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12146             res_df = self.quantile(
#   12147                 [q],  # type: ignore[list-item]
#   12148                 axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   12189             )
#   12190         if method == "single":
# > 12191             res = data._mgr.quantile(qs=q, interpolation=interpolation)
# ...

# %%
nba['Salary'].quantile(0.75) # 75 percentile level of salary; 3rd quartile level
# Out:
# 10129574.25

# %%
nba['Salary'].quantile(0.25) # 25 percentile level of salary; 1st quartile level
# Out:
# 1618520.0

# %%
nba['Salary'].quantile(0.5) # 50 percentile level of salary; 2nd quartile level
# Out:
# 3303074.5

# %%
nba['Salary'].quantile(1) # max
# Out:
# 40231758.0

# %%
nba['Salary'].quantile(0) # min
# Out:
# 79568.0

# %%
nba['Salary'].std()
# Out:
# 9288810.298497694

# %%
nba.sum(numeric_only = True)
# Out:
# Salary    3444112694
# dtype: int64

# %%
nba.mean(numeric_only = True)
# Out:
# Salary    7.653584e+06
# dtype: float64

# %%
nba.median(numeric_only = True)
# Out:
# Salary    3303074.5
# dtype: float64

# %%
nba.quantile(0.75, numeric_only=True)
# Out:
# Salary    10129574.25
# Name: 0.75, dtype: float64

# %%
nba.std(numeric_only = True)
# Out:
# Salary    9.288810e+06
# dtype: float64

# %% [markdown]
# # Vectorized Operations

# %%
nba['Salalry_2x'] = nba['Salary'] + nba['Salary']
nba
# Out:
#                Name                 Team Position   Birthday    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
#      Salalry_2x
# 0       2891394
# 1       3290714
# 2       7663680
# 3      14634148
# 4        159136
# ...

# %%
nba["Name_w_Position"] = nba["Name"] + " (" + nba["Position"] + ")"
nba
# Out:
#                Name                 Team Position   Birthday    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
#      Salalry_2x      Name_w_Position
# 0       2891394    Shake Milton (SG)
# 1       3290714  Christian Wood (PF)
# ...

# %%
nba["Salary_minus_Mean"] = nba["Salary"] - nba["Salary"].mean()
nba
# Out:
#                Name                 Team Position   Birthday    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
#      Salalry_2x      Name_w_Position  Salary_minus_Mean
# 0       2891394    Shake Milton (SG)      -6.207887e+06
# ...

# %% [markdown]
# # Variable operations

# %%
nba['Salary_k'] = nba['Salary'] / 1000
# nba['Salary_2x'] = nba['Salary'] + nba['Salary']
nba['Salary_3x'] = nba['Salary'] * 3
nba
# Out:
#                Name                 Team Position   Birthday    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
#      Salalry_2x      Name_w_Position  Salary_minus_Mean   Salary_k  Salary_3x
# ...

# %%
nba['One'] = nba['Salary'] / nba['Salary']
nba
# Out:
#                Name                 Team Position   Birthday    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
#      Salalry_2x      Name_w_Position  Salary_minus_Mean   Salary_k  Salary_3x  \
# ...

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary', 'Salalry_2x',
#        'Name_w_Position', 'Salary_minus_Mean', 'Salary_k', 'Salary_3x', 'One'],
#       dtype='object')

# %%
nba = nba.drop(columns= ['Salalry_2x', 'Salary_3x', 'Salary_k', 'One'])

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Birthday', 'Salary', 'Name_w_Position',
#        'Salary_minus_Mean'],
#       dtype='object')

# %%
nba.columns = ['Name', 'Team', 'Position', 'Date of Birth', 'Salary', 'Name_w_Position',
       'Salary_minus_Mean']
nba
# Out:
#                Name                 Team Position Date of Birth    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG    1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF    1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF    1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG    1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G    1995-07-26     79568
# ..              ...                  ...      ...           ...       ...
# 445   Austin Rivers      Houston Rockets       PG    1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF    1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C    1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG    1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG    1990-10-21  16200000
#
#          Name_w_Position  Salary_minus_Mean
# ...

# %%
nba.rename(columns = {'Name' : 'First_Last_Name'})
# Out:
#     First Last Name                 Team Position Date of Birth    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG    1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF    1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF    1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG    1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G    1995-07-26     79568
# ..              ...                  ...      ...           ...       ...
# 445   Austin Rivers      Houston Rockets       PG    1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF    1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C    1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG    1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG    1990-10-21  16200000
#
#          Name_w_Position  Salary_minus_Mean
# ...

# %%
nba2
# Out:
#                                Team Position   Birthday    Salary
# Name
# Shake Milton     Philadelphia 76ers       SG 1996-09-26   1445697
# Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# PJ Washington     Charlotte Hornets       PF 1998-08-23   3831840
# Derrick Rose        Detroit Pistons       PG 1988-10-04   7317074
# Marial Shayok    Philadelphia 76ers        G 1995-07-26     79568
# ...                             ...      ...        ...       ...
# Austin Rivers       Houston Rockets       PG 1992-08-01   2174310
# Harry Giles        Sacramento Kings       PF 1998-04-22   2578800
# Robin Lopez         Milwaukee Bucks        C 1988-04-01   4767000
# Collin Sexton   Cleveland Cavaliers       PG 1999-01-04   4764960
# Ricky Rubio            Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 4 columns]

# %%
nba2.rename(index = {'Shake Milton' : 'Shake Milton NBA Player'})
# Out:
#                                         Team Position   Birthday    Salary
# Name
# Shake Milton NBA Player   Philadelphia 76ers       SG 1996-09-26   1445697
# Christian Wood               Detroit Pistons       PF 1995-09-27   1645357
# PJ Washington              Charlotte Hornets       PF 1998-08-23   3831840
# Derrick Rose                 Detroit Pistons       PG 1988-10-04   7317074
# Marial Shayok             Philadelphia 76ers        G 1995-07-26     79568
# ...                                      ...      ...        ...       ...
# Austin Rivers                Houston Rockets       PG 1992-08-01   2174310
# Harry Giles                 Sacramento Kings       PF 1998-04-22   2578800
# Robin Lopez                  Milwaukee Bucks        C 1988-04-01   4767000
# Collin Sexton            Cleveland Cavaliers       PG 1999-01-04   4764960
# Ricky Rubio                     Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 4 columns]

# %%
new_df = nba[['Name', 'Position', "Salary"]]
new_df
# Out:
#                Name Position    Salary
# 0      Shake Milton       SG   1445697
# 1    Christian Wood       PF   1645357
# 2     PJ Washington       PF   3831840
# 3      Derrick Rose       PG   7317074
# 4     Marial Shayok        G     79568
# ..              ...      ...       ...
# 445   Austin Rivers       PG   2174310
# 446     Harry Giles       PF   2578800
# 447     Robin Lopez        C   4767000
# 448   Collin Sexton       PG   4764960
# 449     Ricky Rubio       PG  16200000
#
# [450 rows x 3 columns]

# %%
new_df2 = nba[[ "Salary", 'Name', 'Position']]
new_df2
# Out:
#        Salary            Name Position
# 0     1445697    Shake Milton       SG
# 1     1645357  Christian Wood       PF
# 2     3831840   PJ Washington       PF
# 3     7317074    Derrick Rose       PG
# 4       79568   Marial Shayok        G
# ..        ...             ...      ...
# 445   2174310   Austin Rivers       PG
# 446   2578800     Harry Giles       PF
# 447   4767000     Robin Lopez        C
# 448   4764960   Collin Sexton       PG
# 449  16200000     Ricky Rubio       PG
#
# [450 rows x 3 columns]

# %%
nba
# Out:
#                Name                 Team Position Date of Birth    Salary  \
# 0      Shake Milton   Philadelphia 76ers       SG    1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF    1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF    1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG    1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G    1995-07-26     79568
# ..              ...                  ...      ...           ...       ...
# 445   Austin Rivers      Houston Rockets       PG    1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF    1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C    1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG    1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG    1990-10-21  16200000
#
#          Name_w_Position  Salary_minus_Mean
# ...

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Date of Birth', 'Salary',
#        'Name_w_Position', 'Salary_minus_Mean'],
#       dtype='object')

# %%
nba = nba[['Name_w_Position', 'Name', 'Team', 'Position', 'Date of Birth', 'Salary',
       'Salary_minus_Mean']]
nba
# Out:
#          Name_w_Position            Name                 Team Position  \
# 0      Shake Milton (SG)    Shake Milton   Philadelphia 76ers       SG
# 1    Christian Wood (PF)  Christian Wood      Detroit Pistons       PF
# 2     PJ Washington (PF)   PJ Washington    Charlotte Hornets       PF
# 3      Derrick Rose (PG)    Derrick Rose      Detroit Pistons       PG
# 4      Marial Shayok (G)   Marial Shayok   Philadelphia 76ers        G
# ..                   ...             ...                  ...      ...
# 445   Austin Rivers (PG)   Austin Rivers      Houston Rockets       PG
# 446     Harry Giles (PF)     Harry Giles     Sacramento Kings       PF
# 447      Robin Lopez (C)     Robin Lopez      Milwaukee Bucks        C
# 448   Collin Sexton (PG)   Collin Sexton  Cleveland Cavaliers       PG
# 449     Ricky Rubio (PG)     Ricky Rubio         Phoenix Suns       PG
#
#     Date of Birth    Salary  Salary_minus_Mean
# 0      1996-09-26   1445697      -6.207887e+06
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name_w_Position    450 non-null    object
#  1   Name               450 non-null    object
#  2   Team               450 non-null    object
#  3   Position           450 non-null    object
#  4   Date of Birth      450 non-null    datetime64[ns]
#  5   Salary             450 non-null    int64
#  6   Salary_minus_Mean  450 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 24.7+ KB

# %% [markdown]
# # Convert DataTypes

# %%
emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")
emp
# Out:
#      First Name  Gender Start Date    Salary   Mgmt          Team
# 0       Douglas    Male     8/6/93       NaN   True     Marketing
# 1        Thomas    Male    3/31/96   61933.0   True           NaN
# 2         Maria  Female        NaN  130590.0  False       Finance
# 3         Jerry     NaN     3/4/05  138705.0   True       Finance
# 4         Larry    Male    1/24/98  101004.0   True            IT
# ...         ...     ...        ...       ...    ...           ...
# 996     Phillip    Male    1/31/84   42392.0  False       Finance
# 997     Russell    Male    5/20/13   96914.0  False       Product
# 998       Larry    Male    4/20/13   60500.0  False  Business Dev
# 999      Albert    Male    5/15/12  129949.0   True         Sales
# 1000        NaN     NaN        NaN       NaN    NaN           NaN
#
# [1001 rows x 6 columns]

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    object
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 47.1+ KB

# %%
emp['Mgmt'].astype(bool)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 996     False
# 997     False
# 998     False
# 999      True
# 1000     True
# Name: Mgmt, Length: 1001, dtype: bool

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    object
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 47.1+ KB

# %% [markdown]
# memory usage: 47.1+ KB

# %%
emp["Salary"].astype(int)
emp['Mgmt'] = emp['Mgmt'].astype(bool)
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    object
#  3   Salary      999 non-null    float64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), float64(1), object(4)
# memory usage: 40.2+ KB

# %% [markdown]
# memory usage: 40.2+ KB

# %%
emp["Salary"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-63-09e98607130a> in <cell line: 0>()
# ----> 1 emp["Salary"].astype(int)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
emp['Salary'].fillna(0)
# Out:
# 0            0.0
# 1        61933.0
# 2       130590.0
# 3       138705.0
# 4       101004.0
#           ...
# 996      42392.0
# 997      96914.0
# 998      60500.0
# 999     129949.0
# 1000         0.0
# Name: Salary, Length: 1001, dtype: float64

# %%
(
    emp['Salary']
    .fillna(0)
    .astype(int)
)
# Out:
# 0            0
# 1        61933
# 2       130590
# 3       138705
# 4       101004
#          ...
# 996      42392
# 997      96914
# 998      60500
# 999     129949
# 1000         0
# Name: Salary, Length: 1001, dtype: int64

# %%
emp['Salary'] = (
    emp['Salary']
    .fillna(0)
    .astype(int)
)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    object
#  3   Salary      1001 non-null   int64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), int64(1), object(4)
# memory usage: 40.2+ KB

# %%
emp['Gender'].value_counts()
# Out:
# Gender
# Female    431
# Male      423
# Name: count, dtype: int64

# %%
emp['Gender'] = emp['Gender'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    object
#  3   Salary      1001 non-null   int64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), category(1), int64(1), object(3)
# memory usage: 33.5+ KB

# %%
emp["Start Date"] = pd.to_datetime(emp["Start Date"])
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), int64(1), object(2)
# memory usage: 33.5+ KB
# <ipython-input-72-cef0d51196aa>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   emp["Start Date"] = pd.to_datetime(emp["Start Date"])

# %%
emp
# NaT : missing value for datetime format variable
# Out:
#      First Name  Gender Start Date  Salary   Mgmt          Team
# 0       Douglas    Male 1993-08-06       0   True     Marketing
# 1        Thomas    Male 1996-03-31   61933   True           NaN
# 2         Maria  Female        NaT  130590  False       Finance
# 3         Jerry     NaN 2005-03-04  138705   True       Finance
# 4         Larry    Male 1998-01-24  101004   True            IT
# ...         ...     ...        ...     ...    ...           ...
# 996     Phillip    Male 1984-01-31   42392  False       Finance
# 997     Russell    Male 2013-05-20   96914  False       Product
# 998       Larry    Male 2013-04-20   60500  False  Business Dev
# 999      Albert    Male 2012-05-15  129949   True         Sales
# 1000        NaN     NaN        NaT       0   True           NaN
#
# [1001 rows x 6 columns]

# %%
emp["Start Date"] = emp["Start Date"].astype('datetime64[ns]')
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), int64(1), object(2)
# memory usage: 33.5+ KB

# %%
emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    object
#  2   Start Date  999 non-null    object
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 47.1+ KB

# %%
emp = pd.read_csv("https://bcdanl.github.io/data/employment.csv")

emp["Salary"] = emp["Salary"].fillna(0)
emp = emp.astype({'Mgmt': 'bool',
                  'Salary': 'int',
                  'Gender': 'category',
                  'Start Date': 'datetime64[ns]',
                  'Team': 'category'})
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      1001 non-null   int64
#  4   Mgmt        1001 non-null   bool
#  5   Team        957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](1), int64(1), object(1)
# memory usage: 27.0+ KB

# %%
(47.1-27)/47.1
# Out:
# 0.4267515923566879
