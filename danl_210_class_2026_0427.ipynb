# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_class_2026_0427.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Classwork 16

# %%
import pandas as pd
import numpy as np

# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
flights = pd.read_csv("https://bcdanl.github.io/data/flights.zip")
airlines = pd.read_csv("https://bcdanl.github.io/data/flights-airlines.csv")
airports = pd.read_csv("https://bcdanl.github.io/data/flights-airports.csv")
planes = pd.read_csv("https://bcdanl.github.io/data/flights-planes.csv")
weather = pd.read_csv("https://bcdanl.github.io/data/flights-weather.csv")

# %% [markdown]
# ## Q1
# Merge the flights and weather DataFrames so that all observations from flights are retained in the resulting DataFrame.

# %%
flights
# Out:
# ...
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
weather
# Out:
# ...
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0        EWR  2013      1    1     1  39.02  26.06  59.37     270.0
# 1        EWR  2013      1    1     2  39.02  26.96  61.63     250.0
# 2        EWR  2013      1    1     3  39.02  28.04  64.43     240.0
# 3        EWR  2013      1    1     4  39.92  28.04  62.21     250.0
# 4        EWR  2013      1    1     5  39.02  28.04  64.43     260.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...       ...
# 26110    LGA  2013     12   30    14  35.96  19.94  51.78     340.0
# 26111    LGA  2013     12   30    15  33.98  17.06  49.51     330.0
# 26112    LGA  2013     12   30    16  32.00  15.08  49.19     340.0
# 26113    LGA  2013     12   30    17  30.92  12.92  46.74     320.0
# 26114    LGA  2013     12   30    18  28.94  10.94  46.41     330.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# ...

# %%
q1 = (
    flights
    .merge(
        weather,
        on = ['year', 'month', 'day', 'hour', 'origin'],
        how = 'left'
    )
)

q1.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour_x', 'temp', 'dewp', 'humid', 'wind_dir', 'wind_speed',
#        'wind_gust', 'precip', 'pressure', 'visib', 'time_hour_y'],
#       dtype='object')

# %%
q1.shape
# Out:
# (336776, 29)

# %%
flights.shape
# Out:
# (336776, 19)

# %%
q1_inner = (
    flights
    .merge(
        weather,
        on = ['year', 'month', 'day', 'hour', 'origin']
    )
)

q1_inner.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour_x', 'temp', 'dewp', 'humid', 'wind_dir', 'wind_speed',
#        'wind_gust', 'precip', 'pressure', 'visib', 'time_hour_y'],
#       dtype='object')

# %%
q1_inner.shape
# Out:
# (335220, 29)

# %% [markdown]
# ## Q2
# Identify the airlines (by full name) that have the top five dep_delay values in the flights DataFrame.

# %%
airlines
# Out:
#    carrier                         name
# 0       9E            Endeavor Air Inc.
# 1       AA       American Airlines Inc.
# 2       AS         Alaska Airlines Inc.
# 3       B6              JetBlue Airways
# 4       DL         Delta Air Lines Inc.
# 5       EV     ExpressJet Airlines Inc.
# 6       F9       Frontier Airlines Inc.
# 7       FL  AirTran Airways Corporation
# 8       HA       Hawaiian Airlines Inc.
# 9       MQ                    Envoy Air
# 10      OO        SkyWest Airlines Inc.
# 11      UA        United Air Lines Inc.
# 12      US              US Airways Inc.
# 13      VX               Virgin America
# 14      WN       Southwest Airlines Co.
# 15      YV           Mesa Airlines Inc.

# %%
top5_delay = (
    flights
    .nlargest(5, 'dep_delay', keep="all")
)

top5_delay
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 7072    2013      1    9     641.0             900     1301.0    1242.0
# 235778  2013      6   15    1432.0            1935     1137.0    1607.0
# 8239    2013      1   10    1121.0            1635     1126.0    1239.0
# 327043  2013      9   20    1139.0            1845     1014.0    1457.0
# 270376  2013      7   22     845.0            1600     1005.0    1044.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 7072              1530     1272.0      HA      51  N384HA    JFK  HNL
# 235778            2120     1127.0      MQ    3535  N504MQ    JFK  CMH
# 8239              1810     1109.0      MQ    3695  N517MQ    EWR  ORD
# 327043            2210     1007.0      AA     177  N338AA    JFK  SFO
# 270376            1815      989.0      MQ    3075  N665MQ    JFK  CVG
#
#         air_time  distance  hour  minute             time_hour
# ...

# %%
q2 = (
    top5_delay
    .merge(
        airlines,
        on = ['carrier']
    )
)

q2
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    9     641.0             900     1301.0    1242.0
# 1  2013      6   15    1432.0            1935     1137.0    1607.0
# 2  2013      1   10    1121.0            1635     1126.0    1239.0
# 3  2013      9   20    1139.0            1845     1014.0    1457.0
# 4  2013      7   22     845.0            1600     1005.0    1044.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0            1530     1272.0      HA      51  N384HA    JFK  HNL     640.0
# 1            2120     1127.0      MQ    3535  N504MQ    JFK  CMH      74.0
# 2            1810     1109.0      MQ    3695  N517MQ    EWR  ORD     111.0
# 3            2210     1007.0      AA     177  N338AA    JFK  SFO     354.0
# 4            1815      989.0      MQ    3075  N665MQ    JFK  CVG      96.0
#
#    distance  hour  minute             time_hour                    name
# ...

# %% [markdown]
# ## Q3
# Consider the following two airlines:
#
# - Delta Air Lines Inc. (DL)
# - United Air Lines Inc. (UA)
#
# - Determine which airline has a higher proportion of flights with a dep_delay greater than 30 minutes.
#
# Hint: np.where() can be very useful.

# %%
dl_ua = (
    flights[
        ( flights['carrier'] == "DL" ) | ( flights['carrier'] == "UA" )
    ]
)

dl_ua['carrier'].unique()
# Out:
# array(['UA', 'DL'], dtype=object)

# %%
dl_ua['is_30m_delay'] = np.where(
    dl_ua['dep_delay'] > 30, 1, 0
)

dl_ua
# Out:
# ...
# /tmp/ipykernel_5224/3397508227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dl_ua['is_30m_delay'] = np.where(
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336728  2013      9   30    2055.0            2059       -4.0    2158.0
# ...

# %%
dl_ua = dl_ua[['carrier', 'is_30m_delay']]
dl_ua
# Out:
# ...
#        carrier  is_30m_delay
# 0           UA             0
# 1           UA             0
# 4           DL             0
# 5           UA             0
# 12          UA             0
# ...        ...           ...
# 336728      UA             0
# 336737      UA             0
# 336744      DL             0
# 336755      UA             0
# 336762      UA             1
#
# [106775 rows x 2 columns]

# %%
dl_ua_count = (
    dl_ua[['carrier', 'is_30m_delay']]
    .value_counts()
    .reset_index()
)
# Out:
#   carrier  is_30m_delay  count
# 0      UA             0  51048
# 1      DL             0  43128
# 2      UA             1   7617
# 3      DL             1   4982

# %%
dl_count = (
    dl_ua_count
    .query('carrier == "DL"')
)

ua_count = (
    dl_ua_count
    .query('carrier == "UA"')
)

# %%
dl_count
# Out:
#   carrier  is_30m_delay  count
# 1      DL             0  43128
# 3      DL             1   4982

# %%
4982 / (43128 + 4982)
# Out:
# 0.10355435460403242

# %%
ua_count
# Out:
#   carrier  is_30m_delay  count
# 0      UA             0  51048
# 2      UA             1   7617

# %%
7617 / (51048 + 7617)
# Out:
# 0.129838915878292

# %% [markdown]
# # UDF

# %%
def my_half(x):
  return x / 2

# %%
my_half(2)
# Out:
# 1.0

# %%
my_half(4)
# Out:
# 2.0

# %%
my_half(10)
# Out:
# 5.0

# %%
equiv_my_half = lambda x : x / 2

# %%
equiv_my_half(1)
# Out:
# 0.5

# %%
equiv_my_half(10)
# Out:
# 5.0

# %%
def my_ratio(x, y):
    return x / y

my_ratio(4, 2)
# Out:
# 2.0

# %%
my_ratio(2, 4)
# Out:
# 0.5

# %%
equiv_my_ratio = lambda x, y: x / y

equiv_my_ratio(4, 2)
# Out:
# 2.0

# %%
equiv_my_ratio(2, 4)
# Out:
# 0.5
