# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_class_2026_0508.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# Below is for an interactive display of DataFrame in Colab
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('tableau-colorblind10')

# %%
titanic = sns.load_dataset('titanic')
tips = sns.load_dataset('tips')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sns.countplot(data = titanic,
              x =  'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data = titanic,
              x = 'sex',
              hue = 'survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.histplot(data = titanic,
             x =  'age',
             bins = 5)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data = titanic,
             x =  'age',
             bins = 25)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data = titanic,
             x =  'age',
             binwidth = 1)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(data = tips,
            y = 'total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(data = tips,
            x = 'time',
            y = 'total_bill')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(data = tips,
            x = 'time',
            y = 'total_bill',
            hue = 'time')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(data = tips,
            x = 'time',
            y = 'total_bill',
            hue = 'smoker')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.scatterplot(data = tips,
                x = 'total_bill',
                y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips,
                x = 'total_bill',
                y = 'tip',
                hue = 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data = tips,
           x = 'total_bill',
           y = 'tip')

# %%
sns.scatterplot(data = tips,
                x = 'total_bill',
                y = 'tip',
                alpha = .25)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data = tips,
                x = 'total_bill',
                y = 'tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data = tips,
           x = 'total_bill',
           y = 'tip',
           scatter_kws = {'alpha' : 0.25})

# %%
sns.lmplot(data = tips,
           x = 'total_bill',
           y = 'tip',
           scatter_kws = {'alpha' : 0.5})

# %%
sns.lmplot(data = tips,
           x = 'total_bill',
           y = 'tip',
           hue = 'smoker',
           scatter_kws = {'alpha' : 0.5})

# %%
path_csv = 'https://bcdanl.github.io/data/dji.csv'
dow = pd.read_csv(path_csv,
                  parse_dates= ['Date'])
dow
# Out:
#            Date          Open          High           Low         Close  \
# 0    2005-01-28  10470.580078  10488.389648  10386.559570  10427.200195
# 1    2005-01-31  10428.759766  10510.190430  10428.759766  10489.940430
# 2    2005-02-01  10489.719727  10570.259766  10489.639648  10551.940430
# 3    2005-02-02  10551.049805  10616.370117  10544.480469  10596.790039
# 4    2005-02-03  10592.209961  10601.150391  10550.089844  10593.099609
# ...         ...           ...           ...           ...           ...
# 3433 2018-09-18  26076.210938  26317.339844  26076.210938  26246.960938
# 3434 2018-09-19  26287.839844  26464.410156  26280.759766  26405.759766
# 3435 2018-09-20  26519.390625  26697.490234  26519.390625  26656.980469
# 3436 2018-09-21  26726.250000  26769.160156  26680.369141  26743.500000
# 3437 2018-09-24  26705.250000  26709.939453  26548.679688  26562.050781
#
#          Adj Close     Volume
# 0     10427.200195  358720000
# 1     10489.940430  298060000
# 2     10551.940430  283800000
# 3     10596.790039  279860000
# 4     10593.099609  229000000
# ...            ...        ...
# 3433  26246.960938  243000000
# 3434  26405.759766  251330000
# 3435  26656.980469  260480000
# 3436  26743.500000  657620000
# 3437  26562.050781  254854178
#
# [3438 rows x 7 columns]

# %%
sns.lineplot(data = dow,
             x =  'Date',
             y =  'Close')
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
# New data
healthexp = (
  sns.load_dataset("healthexp")
  .sort_values(["Country", "Year"])
  .query("Year <= 2020")
  )

sns.lineplot(data = healthexp,
             x =  'Year',
             y =  'Life_Expectancy',
             hue = 'Country')
# Out:
# <Axes: xlabel='Year', ylabel='Life_Expectancy'>

# %%
(
 sns.FacetGrid(
       data = titanic,
       row='class',
       col='sex')
 .map(sns.histplot, 'age')
 )

# %%
sns.lmplot(data = tips,
           x = 'total_bill', y = 'tip',
           hue = 'smoker',
           scatter_kws = {'alpha' : 0.5},
           col = 'smoker')
