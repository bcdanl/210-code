# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_script_2025_0210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CW 4.8
# Import the pandas library as pd.

# %%
import pandas

# %%
url = "https://bcdanl.github.io/data/dominick_oj.csv"
df = pandas.read_csv(url)
df
# Out:
#          sales  price      brand  ad
# 0       8256.0   3.87  tropicana   0
# 1       6144.0   3.87  tropicana   0
# 2       3840.0   3.87  tropicana   0
# 3       8000.0   3.87  tropicana   0
# 4       8896.0   3.87  tropicana   0
# ...        ...    ...        ...  ..
# 28942   2944.0   2.00  dominicks   0
# 28943   4928.0   1.94  dominicks   0
# 28944  13440.0   1.59  dominicks   0
# 28945  55680.0   1.49  dominicks   0
# 28946   7040.0   1.75  dominicks   0
#
# [28947 rows x 4 columns]

# %%
import pandas as pd
url = "https://bcdanl.github.io/data/dominick_oj.csv"
df = pd.read_csv(url)
df
# Out:
#          sales  price      brand  ad
# 0       8256.0   3.87  tropicana   0
# 1       6144.0   3.87  tropicana   0
# 2       3840.0   3.87  tropicana   0
# 3       8000.0   3.87  tropicana   0
# 4       8896.0   3.87  tropicana   0
# ...        ...    ...        ...  ..
# 28942   2944.0   2.00  dominicks   0
# 28943   4928.0   1.94  dominicks   0
# 28944  13440.0   1.59  dominicks   0
# 28945  55680.0   1.49  dominicks   0
# 28946   7040.0   1.75  dominicks   0
#
# [28947 rows x 4 columns]
# ...

# %% [markdown]
# Install the itables library.

# %%
# !pip install itables

# !pip install itables
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# From itables, import the functions init_notebook_mode and show.

# %%
from itables import init_notebook_mode, show

# %%
show(df)
# Out:
# <table id="itables_db9f37ca_b3c8_4532_a836_b9b59b9000ee" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>sales</th>
#       <th>price</th>
#       <th>brand</th>
#       <th>ad</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
# ...

# %% [markdown]
# # Loading Data

# %%
import pandas as pd
df = pd.read_csv("https://bcdanl.github.io/data/nba.csv")

# %%
df
# Out:
#                Name                 Team Position  Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG   9/26/96   1445697
# 1    Christian Wood      Detroit Pistons       PF   9/27/95   1645357
# 2     PJ Washington    Charlotte Hornets       PF   8/23/98   3831840
# 3      Derrick Rose      Detroit Pistons       PG   10/4/88   7317074
# 4     Marial Shayok   Philadelphia 76ers        G   7/26/95     79568
# ..              ...                  ...      ...       ...       ...
# 445   Austin Rivers      Houston Rockets       PG    8/1/92   2174310
# 446     Harry Giles     Sacramento Kings       PF   4/22/98   2578800
# 447     Robin Lopez      Milwaukee Bucks        C    4/1/88   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG    1/4/99   4764960
# 449     Ricky Rubio         Phoenix Suns       PG  10/21/90  16200000
#
# [450 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
                 parse_dates=["Birthday"])
df
# Out:
# <ipython-input-12-bbc9f5dc61a2>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("https://bcdanl.github.io/data/nba.csv",
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# ...

# %% [markdown]
# # Mounting Google Drive

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/nielsen-dma-us.csv"
dma = pd.read_csv(path)
dma
# Out:
#                                               DMA Code  \
# 0                                                  500
# 1                                                  501
# 2                                                  502
# 3                                                  503
# 4                                                  504
# ..                                                 ...
# 206                                                862
# 207                                                866
# 208                                                868
# 209                                                881
# 210  Note: unless noted below, U.S. counties are as...
#
#                                               DMA Name
# 0                                      PORTLAND-AUBURN
# 1                                             NEW YORK
# 2                                           BINGHAMTON
# 3                                                MACON
# ...

# %%
files.upload()
# Out:
#      <input type="file" id="files-6402bdfd-25ee-4791-a98a-59ea400ec187" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6402bdfd-25ee-4791-a98a-59ea400ec187">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_ex = pd.read_csv("/original.csv")

df_ex
# Out:
#        id  first_name   last_name  gender           City  \
# 0       1     Melinde   Shilburne  Female      Nowa Ruda
# 1       2    Kimberly  Von Welden  Female         Bulgan
# 2       3      Alvera    Di Boldi  Female            NaN
# 3       4     Shannon   O'Griffin    Male  Divnomorskoye
# 4       5    Sherwood     Macieja    Male      Mytishchi
# ..    ...         ...         ...     ...            ...
# 995   996      Kathye     Grasser  Female       Dzaoudzi
# 996   997     Haskell    Kempston    Male  Ban Talat Nua
# 997   998  Holly-anne       Gerbl  Female        Guanaja
# 998   999      Marysa      Purdie  Female          Sioah
# 999  1000      Jewell    Haselden  Female    Springfield
#
#                                  JobTitle     Salary   Latitude   Longitude
# 0                     Assistant Professor  $57438.18  50.577407   16.496718
# 1                           Programmer II  $62846.60  48.823157  103.521820
# ...

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()  # Enabling an interactive DataFrame display
df
# Out:
#                Name                 Team Position   Birthday    Salary
# 0      Shake Milton   Philadelphia 76ers       SG 1996-09-26   1445697
# 1    Christian Wood      Detroit Pistons       PF 1995-09-27   1645357
# 2     PJ Washington    Charlotte Hornets       PF 1998-08-23   3831840
# 3      Derrick Rose      Detroit Pistons       PG 1988-10-04   7317074
# 4     Marial Shayok   Philadelphia 76ers        G 1995-07-26     79568
# ..              ...                  ...      ...        ...       ...
# 445   Austin Rivers      Houston Rockets       PG 1992-08-01   2174310
# 446     Harry Giles     Sacramento Kings       PF 1998-04-22   2578800
# 447     Robin Lopez      Milwaukee Bucks        C 1988-04-01   4767000
# 448   Collin Sexton  Cleveland Cavaliers       PG 1999-01-04   4764960
# 449     Ricky Rubio         Phoenix Suns       PG 1990-10-21  16200000
#
# [450 rows x 5 columns]
