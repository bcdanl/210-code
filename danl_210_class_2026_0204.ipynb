# %% [markdown]
# <a href="https://colab.research.google.com/github/bcdanl/210-code/blob/main/danl_210_class_2026_0204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst_nums = [0, 1, 2, 3, 4]

for num in lst_nums:
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
word = 'thud'
for letter in word:
    print(letter)
# Out:
# t
# h
# u
# d

# %%
word = 'thud'
offset = 0
while offset < len(word):
    print(word[offset])
    offset += 1
# Out:
# t
# h
# u
# d

# %%
offset
# Out:
# 4

# %% [markdown]
# ## Classwork 2.6

# %%
vals = [3, 2, 1, 0]

# %%
len(vals)
# Out:
# 4

# %% [markdown]
# ### (a)
# Use a while loop to print each value of the list [3, 2, 1, 0], one at a time.

# %%
vals = [3, 2, 1, 0]
counter = 0

while counter < len(vals):
  print(vals[counter])
  counter += 1
# Out:
# 3
# 2
# 1
# 0

# %%
vals = [3, 2, 1, 0]
counter = 0

while counter <= len(vals):
  print(vals[counter])
  counter += 1
# Out:
# 3
# 2
# 1
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-613763770.py in <cell line: 0>()
#       3
#       4 while counter <= len(vals):
# ----> 5   print(vals[counter])
#       6   counter += 1
#
# IndexError: list index out of range

# %%
counter
# Out:
# 4

# %%
vals[counter]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2721804013.py in <cell line: 0>()
# ----> 1 vals[counter]
#
# IndexError: list index out of range

# %% [markdown]
# ### (b)
# Use a for loop to print each value of the list [3, 2, 1, 0], one at a time.

# %%
vals = [3, 2, 1, 0]

for val in vals:
  print(val)
# Out:
# 3
# 2
# 1
# 0

# %%
vals = [3, 2, 1, 0]

for v in vals:
  print(v)
# Out:
# 3
# 2
# 1
# 0

# %%
range(1, 4)
# Out:
# range(1, 4)

# %%
type(range(1, 4))
# Out:
# range

# %%
list( range(1, 4) )
# Out:
# [1, 2, 3]

# %%
list( range(0, 4) )
# Out:
# [0, 1, 2, 3]

# %%
list( range(4) )
# Out:
# [0, 1, 2, 3]

# %%
list( range(0, 4, 2) )
# Out:
# [0, 2]

# %%
for x in range(0, 4):
    print(x)
# Out:
# 0
# 1
# 2
# 3

# %%
fruits = ["apple", "banana", "orange"]

# default: starts counting at 0
for i, fruit in enumerate(fruits):
    print(i, fruit)
# Out:
# 0 apple
# 1 banana
# 2 orange

# %%
fruits = ["apple", "banana", "orange"]

for i in range(3):
  print( i, fruits[i] )
# Out:
# 0 apple
# 1 banana
# 2 orange

# %%
fruits = ["apple", "banana", "orange"]

# default: starts counting at 1
for i, fruit in enumerate(fruits, start = 1):
    print(i, fruit)
# Out:
# 1 apple
# 2 banana
# 3 orange

# %%
fruits = ["apple", "banana", "orange"]

for i in range(3):
  j = i + 1
  print( j, fruits[i] )
# Out:
# 1 apple
# 2 banana
# 3 orange

# %%
word = 'thud'
for letter in word:
    if letter == 'u':
        break
    print(letter)
# Out:
# t
# h

# %%
word = 'thud'
for letter in word:
    if letter == 'u':
        continue
    print(letter)
# Out:
# t
# h
# d

# %%
for num in range(1, 6):

    if num == 2:
        continue   # skip printing 2

    if num == 3:
        pass       # do nothing, move on

    if num == 4:
        break      # exit the loop

    print(num)
# Out:
# 1
# 3

# %% [markdown]
# ## Classwork 2.7
# Loop Control with Comparisons and Early Exit

# %%
guess_me = 7
number = 1

# %% [markdown]
# ### (a)
#
# Write a while loop that keeps running until you break:
#
# - If number < guess_me, print "too low" and then increment number by 1.
# - If number == guess_me, print "found it!" and then break.
# - If number > guess_me, print "oops" and then break.

# %%
guess_me = 7
number = 1

while True:
  if number < guess_me:
    print("too low")
    number += 1
  elif number == guess_me:
    print("found it!")
    break
  else:
    print("oops")
    break
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %%
number
# Out:
# 7

# %% [markdown]
# ### (b)
# Write the same logic using a for loop that tries values from 1 to 10:
#
# - If the current value is less than guess_me, print "too low".
# - If it equals guess_me, print "found it!" and then break.
# - If it is greater than guess_me, print "oops" and then break.

# %%
guess_me = 7
number = 1

for num in range(1,11):
  if num < guess_me:
    print("too low")
  elif num == guess_me:
    print("found it!")
    break
  else:
    print("oops")
    break
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!
